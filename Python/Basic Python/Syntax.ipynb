# %% [markdown]
# # Syntax

# %% [markdown]
# ####
# Python syntax is like grammer for this programming langauge.
#
# Syntax refers to the set of rules that defines how to write and organize code
# so that the Python Interpreter can understanding and run it correctly.
#
# These rules ensures that your code is structured , formatted and error -free.

# %% [markdown]
# ### Indentation :-
# Python indentation refers to the use of whitespace (4 spaces or 1 tab) at the begining of code line.
#
# The indentation in pythin is very important.
#
# Python uses indentation to indicate a block of code.

# %%
if 5>2:
    print('Five is greater than two')
# Out:
# Five is greater than two

# %%
if 5>2:
print('Five is greater than two')
# Out:
#   Cell In[2], line 2
#     print('Five is greater than two')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# ### Extension :-
# Any file ending with .py is a Python source code file.
#
# main.py
#
# app.py
#
# data_analysis.py
#
# script.py

# %% [markdown]
# ### Comments :-
#
# A comment in Python is a line of text that is ignored by the interpreter .
#
# It is used to explain the code and make it more readable.
#
# **Single line comment(# - Hash)**  --> # This is single line comment.
#
# **Multi-line comment("""    """ - Triple quotes)** --> """This is a mutli- line comments.
#                                                             It spans multiple lines.     """

# %%
import sys
sys.version
# Out:
# '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# ### Identifiers :-
#
# 1.Python is case-sensitive.
#
# 2.In python identifiers are unique names that are assigned to variables, functions, classes, and other entities.
#
# 3.They should start with a letter(a-z),(A-Z),or an underscore(_) and can be followed by letters, numbers (0-9) or underscore.

# %% [markdown]
# #### Example a valid identifers :-

# %%
name = "Alice"

# %%
_age = 35

# %%
totalmarks = 89

# %%
PI = 3.14

# %%
def add number(a,b):
    return a+b
# Out:
#   Cell In[12], line 1
#     def add number(a,b):
#             ^
# SyntaxError: expected '('

# %% [markdown]
# ### Keyword :-
#
# A keyword is a reserved word in Python.
#
# You cannot use it as a variable, function, or class name.

# %%
import k
